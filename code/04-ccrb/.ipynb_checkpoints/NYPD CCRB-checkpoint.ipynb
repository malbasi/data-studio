# %%
import pandas as pd
import matplotlib.pyplot as plt
from pygeocoder import Geocoder
import numpy as np
from cycler import cycler
import re
from pywaffle import Waffle

import glob

# %matplotlib inline

import altair as alt
from vega_datasets import data

# for the notebook only (not for JupyterLab) run this command once per session
alt.renderers.enable('notebook')
# Out:
# RendererRegistry.enable('notebook')

# %%
#Import style
plt.rcdefaults()
plt.rcParams.update({
    'pdf.fonttype': 42,
    'ps.fonttype': 42,
    'font.family': 'Futura Std',
    'font.style' : 'normal',
    'font.weight' : '100',
    'font.stretch' : 'ultra-condensed',
    
    'figure.facecolor'    : '#FDF6E3',

    
    'patch.antialiased'   : True,

    'lines.linewidth'     : 2.0,
    'lines.solid_capstyle': 'butt',

    'axes.titlesize'      : 16,
    'axes.labelsize'      : 12,
    'axes.labelcolor'     : '#657b83',
    'axes.facecolor'      : '#eee8d5',
    'axes.edgecolor'      : '#eee8d5',
    'axes.axisbelow'      : True,
    'axes.prop_cycle'    : cycler('color', ['#268BD2','#d26c3d', '#dbd7ad', '#f6c5af', '#d7da00', '#7db49f', '#86a3ba']),

    'axes.grid'           : False,
    'grid.color'          : '#ffffff',    # grid color
    'grid.linestyle'      : ':',         # line
    'grid.linewidth'      : 1,        # in points

    ### TICKS
    'xtick.color'         : '#657b83',
    'xtick.direction'     : 'out',
    'xtick.labelsize' : 14,
    'ytick.labelsize' : 14,

    'ytick.color'         : '#657b83',
    'ytick.direction'     : 'out',
    
})

# %%
df = pd.read_csv("Civilian_Complaint_Review_Board__CCRB__-_Complaints_Closed.csv")
df.head()
# Out:
#   Extract Run Date  Randomized Id  Closed Year Case Type  \
# 0       05/25/2018              1         2000      CCRB
# 1       05/25/2018              2         2000      CCRB
# 2       05/25/2018              3         2000      CCRB
# 3       05/25/2018              4         2000      CCRB
# 4       05/25/2018              5         2000      CCRB
#
#    Days From Received Date To Case Closing  Re-opened  Ever On DA Hold  \
# 0                                       80      False            False
# 1                                      391      False            False
# 2                                      193      False            False
# 3                                      412      False            False
# 4                                      394      False            False
#
#          Outcome Path           Case Disposition Borough Of Incident  \
# 0           Truncated  Complainant Uncooperative            Brooklyn
# 1  Full Investigation            Unsubstantiated           Manhattan
# 2            Mediated                   Mediated               Bronx
# 3  Full Investigation                  Unfounded           Manhattan
# 4  Full Investigation            Unsubstantiated            Brooklyn
#
#   Patrol Borough Of Incident  Stop, Question, Frisk Complaint
# 0             Brooklyn North                            False
# 1            Manhattan South                             True
# 2                      Bronx                            False
# 3            Manhattan North                            False
# 4             Brooklyn South                            False

# %%
df['Extract Run Date'] = pd.to_datetime(df['Extract Run Date'])

# %%
df['Outcome Path'].value_counts()
# Out:
# Truncated              60942
# Full Investigation     38102
# Mediation Attempted     2553
# Mediated                2195
# Other                    939
# Name: Outcome Path, dtype: int64

# %% [markdown]
# # Waffles!
# ## normalize this by population (of people in borough)
# ## maybe by population of police instead/also

# %%
df['Borough Of Incident'].value_counts()
# Out:
# Brooklyn         34891
# Manhattan        25608
# Bronx            22797
# Queens           16527
# Staten Island     4319
# Outside NYC         97
# Name: Borough Of Incident, dtype: int64

# %%
calculated = df['Borough Of Incident'].value_counts(normalize=True)*100

fig = plt.figure(
    FigureClass=Waffle,
    rows=5,
    values=list(calculated.values),
    labels=list(calculated.index),
    figsize=(11,6),
    legend={'loc':'upper left','bbox_to_anchor': (1.1, 1)},
    colors = ('#268BD2','#d26c3d', '#dbd7ad', '#f6c5af', '#d7da00', '#7db49f')
)

# plt.savefig('borowaffleCsize.svg')

# %%
calculated
# Out:
# Brooklyn         33.472117
# Manhattan        24.566621
# Bronx            21.869934
# Queens           15.854910
# Staten Island     4.143363
# Outside NYC       0.093055
# Name: Borough Of Incident, dtype: float64

# %%
df['Patrol Borough Of Incident'].value_counts()
# Out:
# Bronx              22640
# Brooklyn North     19686
# Brooklyn South     14886
# Manhattan North    13492
# Manhattan South    11614
# Queens South        9673
# Queens North        6760
# Staten Island       4296
# Other               1684
# Name: Patrol Borough Of Incident, dtype: int64

# %%
df['Stop, Question, Frisk Complaint'].value_counts()
# Out:
# False    78067
# True     26664
# Name: Stop, Question, Frisk Complaint, dtype: int64

# %%
df['Days From Received Date To Case Closing'].plot(kind='hist', bins= 49, range=(0,700), figsize=(14,8))
# plt.savefig('histBsize.svg')

# %%
df['Case Disposition'].value_counts()
# Out:
# Complainant Uncooperative                   30796
# Unsubstantiated                             17206
# Complaint Withdrawn                         12477
# Complainant Unavailable                     10341
# Exonerated                                   7001
# Unfounded                                    6914
# Alleged Victim Uncooperative                 4690
# Substantiated (Charges)                      2712
# Mediation Attempted                          2553
# Officer(s) Unidentified                      2254
# Mediated                                     2195
# Alleged Victim Unavailable                   1955
# Substantiated (Command Discipline)            766
# Victim Unidentified                           577
# Substantiated (Formalized Training)           358
# Administratively Closed                       326
# Substantiated (Command Discipline A)          279
# Substantiated (Instructions)                  278
# Substantiated (Command Discipline B)          210
# Miscellaneous - Subject Retired               210
# Miscellaneous                                 194
# Miscellaneous - Subject Resigned              112
# Closed - Pending Litigation                    83
# Substantiated (Command Lvl Instructions)       68
# Duplicate - CCRB                               66
# Substantiated (No Recommendations)             56
# Witness Uncooperative                          18
# Miscellaneous - Subject Terminated             14
# OCD - Staff Referral                            6
# Witness Unavailable                             5
# IAB - Staff Referral                            5
# IAB - Referral                                  3
# Referral                                        2
# Conciliated                                     1
# Name: Case Disposition, dtype: int64

# %%
df.shape
# Out:
# (104731, 12)

# %%
df.groupby(['Closed Year', 'Borough Of Incident'])['Randomized Id'].count().reset_index()
# Out:
#      Closed Year Borough Of Incident  Randomized Id
# 0           2000               Bronx            923
# 1           2000            Brooklyn           1457
# 2           2000           Manhattan           1494
# 3           2000         Outside NYC              6
# 4           2000              Queens            838
# 5           2000       Staten Island            258
# 6           2001               Bronx            687
# 7           2001            Brooklyn           1174
# 8           2001           Manhattan            977
# 9           2001         Outside NYC              6
# 10          2001              Queens            620
# 11          2001       Staten Island            203
# 12          2002               Bronx            937
# 13          2002            Brooklyn           1610
# 14          2002           Manhattan           1250
# 15          2002         Outside NYC              5
# 16          2002              Queens            790
# 17          2002       Staten Island            246
# 18          2003               Bronx            928
# 19          2003            Brooklyn           1470
# 20          2003           Manhattan           1263
# 21          2003         Outside NYC              5
# 22          2003              Queens            743
# 23          2003       Staten Island            199
# 24          2004               Bronx           1236
# 25          2004            Brooklyn           1965
# 26          2004           Manhattan           1669
# 27          2004         Outside NYC              8
# 28          2004              Queens            970
# 29          2004       Staten Island            229
# ..           ...                 ...            ...
# 78          2013               Bronx           1487
# 79          2013            Brooklyn           2415
# 80          2013           Manhattan           1704
# 81          2013         Outside NYC              5
# 82          2013              Queens           1165
# 83          2013       Staten Island            307
# 84          2014               Bronx           1120
# 85          2014            Brooklyn           1804
# 86          2014           Manhattan           1225
# 87          2014         Outside NYC             10
# 88          2014              Queens            884
# 89          2014       Staten Island            277
# 90          2015               Bronx           1166
# 91          2015            Brooklyn           1680
# 92          2015           Manhattan           1194
# 93          2015         Outside NYC              8
# 94          2015              Queens            889
# 95          2015       Staten Island            258
# 96          2016               Bronx            959
# 97          2016            Brooklyn           1406
# 98          2016           Manhattan           1061
# 99          2016         Outside NYC              8
# 100         2016              Queens            752
# 101         2016       Staten Island            190
# 102         2017               Bronx            875
# 103         2017            Brooklyn           1301
# 104         2017           Manhattan            968
# 105         2017         Outside NYC              4
# 106         2017              Queens            700
# 107         2017       Staten Island            173
#
# [108 rows x 3 columns]

# %%
df.count()

# %%
import altair as alt
from vega_datasets import data

source = df.groupby(['Closed Year', 'Borough Of Incident'])['Randomized Id'].count().reset_index()

alt.Chart(source).mark_area().encode(
    x = source['Closed Year'],
    y = source['Randomized Id'],
#     alt.Color('series:N',
#         scale=alt.Scale(scheme='category20b')
#     )
).interactive()
# Out:
# ---------------------------------------------------------------------------
# SchemaValidationError                     Traceback (most recent call last)
# ~/.pyenv/versions/3.6.5/lib/python3.6/site-packages/altair/vegalite/v2/api.py in to_dict(self, *args, **kwargs)
#     338         if dct is None:
#     339             kwargs['validate'] = 'deep'
# --> 340             dct = super(TopLevelMixin, copy).to_dict(*args, **kwargs)
#     341
#     342         if is_top_level:
#
# ~/.pyenv/versions/3.6.5/lib/python3.6/site-packages/altair/utils/schemapi.py in to_dict(self, validate, ignore, context)
#     243             result = _todict(self._args[0])
#     244         elif not self._args:
# --> 245             result = _todict({k: v for k, v in self._kwds.items()
#     246                               if k not in ignore})
#     247         else:
#
# ~/.pyenv/versions/3.6.5/lib/python3.6/site-packages/altair/utils/schemapi.py in _todict(val)
#     235                 return [_todict(v) for v in val]
#     236             elif isinstance(val, dict):
# --> 237                 return {k: _todict(v) for k, v in val.items()
#     238                         if v is not Undefined}
#     239             else:
#
# ~/.pyenv/versions/3.6.5/lib/python3.6/site-packages/altair/utils/schemapi.py in <dictcomp>(.0)
#     236             elif isinstance(val, dict):
#     237                 return {k: _todict(v) for k, v in val.items()
# --> 238                         if v is not Undefined}
#     239             else:
#     240                 return val
#
# ~/.pyenv/versions/3.6.5/lib/python3.6/site-packages/altair/utils/schemapi.py in _todict(val)
#     231         def _todict(val):
#     232             if isinstance(val, SchemaBase):
# --> 233                 return val.to_dict(validate=sub_validate, context=context)
#     234             elif isinstance(val, (list, tuple)):
#     235                 return [_todict(v) for v in val]
#
# ~/.pyenv/versions/3.6.5/lib/python3.6/site-packages/altair/utils/schemapi.py in to_dict(self, validate, ignore, context)
#     243             result = _todict(self._args[0])
#     244         elif not self._args:
# --> 245             result = _todict({k: v for k, v in self._kwds.items()
#     246                               if k not in ignore})
#     247         else:
#
# ~/.pyenv/versions/3.6.5/lib/python3.6/site-packages/altair/utils/schemapi.py in _todict(val)
#     235                 return [_todict(v) for v in val]
#     236             elif isinstance(val, dict):
# --> 237                 return {k: _todict(v) for k, v in val.items()
#     238                         if v is not Undefined}
#     239             else:
#
# ~/.pyenv/versions/3.6.5/lib/python3.6/site-packages/altair/utils/schemapi.py in <dictcomp>(.0)
#     236             elif isinstance(val, dict):
#     237                 return {k: _todict(v) for k, v in val.items()
# --> 238                         if v is not Undefined}
#     239             else:
#     240                 return val
#
# ~/.pyenv/versions/3.6.5/lib/python3.6/site-packages/altair/utils/schemapi.py in _todict(val)
#     231         def _todict(val):
#     232             if isinstance(val, SchemaBase):
# --> 233                 return val.to_dict(validate=sub_validate, context=context)
#     234             elif isinstance(val, (list, tuple)):
#     235                 return [_todict(v) for v in val]
#
# ~/.pyenv/versions/3.6.5/lib/python3.6/site-packages/altair/vegalite/v2/schema/channels.py in to_dict(self, validate, ignore, context)
#      50             validate=validate,
#      51             ignore=ignore,
# ---> 52             context=context
#      53         )
#      54
#
# ~/.pyenv/versions/3.6.5/lib/python3.6/site-packages/altair/utils/schemapi.py in to_dict(self, validate, ignore, context)
#     252                 self.validate(result)
#     253             except jsonschema.ValidationError as err:
# --> 254                 raise SchemaValidationError(self, err)
#     255         return result
#     256
#
# SchemaValidationError: Invalid specification
#
#         altair.vegalite.v2.schema.channels.X->field, validating 'anyOf'
#
#         0      2000
# 1      2000
# 2      2000
# 3      2000
# 4      2000
# 5      2000
# 6      2001
# 7      2001
# 8      2001
# 9      2001
# 10     2001
# 11     2001
# 12     2002
# 13     2002
# 14     2002
# 15     2002
# 16     2002
# 17     2002
# 18     2003
# 19     2003
# 20     2003
# 21     2003
# 22     2003
# 23     2003
# 24     2004
# 25     2004
# 26     2004
# 27     2004
# 28     2004
# 29     2004
#        ...
# 78     2013
# 79     2013
# 80     2013
# 81     2013
# 82     2013
# 83     2013
# 84     2014
# 85     2014
# 86     2014
# 87     2014
# 88     2014
# 89     2014
# 90     2015
# 91     2015
# 92     2015
# 93     2015
# 94     2015
# 95     2015
# 96     2016
# 97     2016
# 98     2016
# 99     2016
# 100    2016
# 101    2016
# 102    2017
# 103    2017
# 104    2017
# 105    2017
# 106    2017
# 107    2017
# Name: Closed Year, Length: 108, dtype: int64 is not valid under any of the given schemas
# Chart({
#   data:      Closed Year Borough Of Incident  Randomized Id
#   0           2000               Bronx            923
#   1           2000            Brooklyn           1457
#   2           2000           Manhattan           1494
#   3           2000         Outside NYC              6
#   4           2000              Queens            838
#   5           2000       Staten Island            258
#   6           2001               Bronx            687
#   7           2001            Brooklyn           1174
#   8           2001           Manhattan            977
#   9           2001         Outside NYC              6
#   10          2001              Queens            620
#   11          2001       Staten Island            203
#   12          2002               Bronx            937
#   13          2002            Brooklyn           1610
#   14          2002           Manhattan           1250
#   15          2002         Outside NYC              5
#   16          2002              Queens            790
#   17          2002       Staten Island            246
#   18          2003               Bronx            928
#   19          2003            Brooklyn           1470
#   20          2003           Manhattan           1263
#   21          2003         Outside NYC              5
#   22          2003              Queens            743
#   23          2003       Staten Island            199
#   24          2004               Bronx           1236
#   25          2004            Brooklyn           1965
#   26          2004           Manhattan           1669
#   27          2004         Outside NYC              8
#   28          2004              Queens            970
#   29          2004       Staten Island            229
#   ..           ...                 ...            ...
#   78          2013               Bronx           1487
#   79          2013            Brooklyn           2415
#   80          2013           Manhattan           1704
#   81          2013         Outside NYC              5
#   82          2013              Queens           1165
#   83          2013       Staten Island            307
#   84          2014               Bronx           1120
#   85          2014            Brooklyn           1804
#   86          2014           Manhattan           1225
#   87          2014         Outside NYC             10
#   88          2014              Queens            884
#   89          2014       Staten Island            277
#   90          2015               Bronx           1166
#   91          2015            Brooklyn           1680
#   92          2015           Manhattan           1194
#   93          2015         Outside NYC              8
#   94          2015              Queens            889
#   95          2015       Staten Island            258
#   96          2016               Bronx            959
#   97          2016            Brooklyn           1406
#   98          2016           Manhattan           1061
#   99          2016         Outside NYC              8
#   100         2016              Queens            752
#   101         2016       Staten Island            190
#   102         2017               Bronx            875
#   103         2017            Brooklyn           1301
#   104         2017           Manhattan            968
#   105         2017         Outside NYC              4
#   106         2017              Queens            700
#   107         2017       Staten Island            173
#
#   [108 rows x 3 columns],
#   encoding: EncodingWithFacet({
#     x: X({
#       shorthand: 0      2000
#       1      2000
#       2      2000
#       3      2000
#       4      2000
#       5      2000
#       6      2001
#       7      2001
#       8      2001
#       9      2001
#       10     2001
#       11     2001
#       12     2002
#       13     2002
#       14     2002
#       15     2002
#       16     2002
#       17     2002
#       18     2003
#       19     2003
#       20     2003
#       21     2003
#       22     2003
#       23     2003
#       24     2004
#       25     2004
#       26     2004
#       27     2004
#       28     2004
#       29     2004
#              ...
#       78     2013
#       79     2013
#       80     2013
#       81     2013
#       82     2013
#       83     2013
#       84     2014
#       85     2014
#       86     2014
#       87     2014
#       88     2014
#       89     2014
#       90     2015
#       91     2015
#       92     2015
#       93     2015
#       94     2015
#       95     2015
#       96     2016
#       97     2016
#       98     2016
#       99     2016
#       100    2016
#       101    2016
#       102    2017
#       103    2017
#       104    2017
#       105    2017
#       106    2017
#       107    2017
#       Name: Closed Year, Length: 108, dtype: int64
#     }),
#     y: Y({
#       shorthand: 0       923
#       1      1457
#       2      1494
#       3         6
#       4       838
#       5       258
#       6       687
#       7      1174
#       8       977
#       9         6
#       10      620
#       11      203
#       12      937
#       13     1610
#       14     1250
#       15        5
#       16      790
#       17      246
#       18      928
#       19     1470
#       20     1263
#       21        5
#       22      743
#       23      199
#       24     1236
#       25     1965
#       26     1669
#       27        8
#       28      970
#       29      229
#              ...
#       78     1487
#       79     2415
#       80     1704
#       81        5
#       82     1165
#       83      307
#       84     1120
#       85     1804
#       86     1225
#       87       10
#       88      884
#       89      277
#       90     1166
#       91     1680
#       92     1194
#       93        8
#       94      889
#       95      258
#       96      959
#       97     1406
#       98     1061
#       99        8
#       100     752
#       101     190
#       102     875
#       103    1301
#       104     968
#       105       4
#       106     700
#       107     173
#       Name: Randomized Id, Length: 108, dtype: int64
#     })
#   }),
#   mark: 'area',
#   selection: SelectionMapping({
#     selector003: SelectionDef({
#       bind: 'scales',
#       encodings: ['x', 'y'],
#       type: 'interval'
#     })
#   })
# })

# %%
source.plot(kind='bar',x='Closed Year', y='Randomized Id', figsize=(20,6))

# %%
source.keys()
# Out:
# Index(['Closed Year', 'Borough Of Incident', 'Randomized Id'], dtype='object')

# %%
source = df.groupby(['Closed Year', 'Borough Of Incident'])['Randomized Id'].count().reset_index()
source.head()
# Out:
#    Closed Year Borough Of Incident  Randomized Id
# 0         2000               Bronx            923
# 1         2000            Brooklyn           1457
# 2         2000           Manhattan           1494
# 3         2000         Outside NYC              6
# 4         2000              Queens            838

# %%
source[source['Borough Of Incident'] == 'Bronx'].plot(kind='area', x='Closed Year', y='Randomized Id', figsize=(10,5))
plt.show()

# %%
df.groupby('Closed Year')['Randomized Id'].count().reset_index().plot(kind='area', x='Closed Year', y='Randomized Id', figsize=(10,5), xticks=(1:10))
plt.show()
