# %% [markdown]
# ### This scraper needs to work in a few discrete steps
# 1) Compile a list of publications and their links<br>
# 2) Loop through that list and scrape pay rate and descriptions<br>
# 3) Join all information together into one df for analysis<br>
# ______<br>

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from selenium.webdriver.support.ui import WebDriverWait
import pandas as pd
import re

# %% [markdown]
# ## Step 1:
# compile a list of publication names and their links

# %%
driver = webdriver.Chrome()
driver.get('http://whopayswriters.com/#/results')

# %%
#find the list of publications in the left side-bar
pub_name = driver.find_element_by_xpath('//*[@id="results"]/div[2]/div[2]/div[1]/ul')
pub_list = pub_name.find_elements_by_tag_name('a')
for list in pub_list[:10]:
    print(list.text)
len(pub_list)
# Out:
# 100 Days In Appalachia
# 3288 Review
# 425 Business
# 435 Magazine
# 5280
# 7x7
# A.v. Club
# A&e Real Crime Blog
# Aarp Bulletin
# Aarp En Español (spanish-language Website For Aarp).
# 1322

# %%
#pull the URL from the pub_list 
publication_list=[]
loop_count = 0
for list in pub_list:
    publications = {}
    #pull the second half of the UR
    link = list.get_attribute('ng-href')
    #append the first, static part of the URL with the second half.
    publications['link'] = "http://whopayswriters.com/" + link
    #grab the publication name
    publications['name'] = list.text
    #save name and link (dict) to list of publications
    publication_list.append(publications)
    loop_count += 1
    print(loop_count, 'out of', len(pub_list))
print(publication_list[:2])
# Out:
# 1 out of 1322
# 2 out of 1322
# 3 out of 1322
# 4 out of 1322
# 5 out of 1322
# 6 out of 1322
# 7 out of 1322
# 8 out of 1322
# 9 out of 1322
# 10 out of 1322
# 11 out of 1322
# 12 out of 1322
# 13 out of 1322
# 14 out of 1322
# 15 out of 1322
# 16 out of 1322
# 17 out of 1322
# 18 out of 1322
# 19 out of 1322
# 20 out of 1322
# 21 out of 1322
# 22 out of 1322
# 23 out of 1322
# 24 out of 1322
# 25 out of 1322
# 26 out of 1322
# 27 out of 1322
# 28 out of 1322
# 29 out of 1322
# 30 out of 1322
# 31 out of 1322
# 32 out of 1322
# 33 out of 1322
# 34 out of 1322
# 35 out of 1322
# 36 out of 1322
# 37 out of 1322
# 38 out of 1322
# 39 out of 1322
# 40 out of 1322
# 41 out of 1322
# 42 out of 1322
# 43 out of 1322
# 44 out of 1322
# 45 out of 1322
# 46 out of 1322
# 47 out of 1322
# 48 out of 1322
# 49 out of 1322
# 50 out of 1322
# 51 out of 1322
# 52 out of 1322
# 53 out of 1322
# 54 out of 1322
# 55 out of 1322
# 56 out of 1322
# 57 out of 1322
# 58 out of 1322
# 59 out of 1322
# 60 out of 1322
# 61 out of 1322
# 62 out of 1322
# 63 out of 1322
# 64 out of 1322
# 65 out of 1322
# 66 out of 1322
# 67 out of 1322
# 68 out of 1322
# 69 out of 1322
# 70 out of 1322
# 71 out of 1322
# 72 out of 1322
# 73 out of 1322
# 74 out of 1322
# 75 out of 1322
# 76 out of 1322
# 77 out of 1322
# 78 out of 1322
# 79 out of 1322
# 80 out of 1322
# 81 out of 1322
# 82 out of 1322
# 83 out of 1322
# 84 out of 1322
# 85 out of 1322
#                                                 link                    name
# 0  http://whopayswriters.com/#/publication/100-da...  100 Days In Appalachia
# 1  http://whopayswriters.com/#/publication/3288-r...             3288 Review
# 2  http://whopayswriters.com/#/publication/425-bu...            425 Business
# 3  http://whopayswriters.com/#/publication/435-ma...            435 Magazine
# 4       http://whopayswriters.com/#/publication/5280                    5280

# %%
df_pubs = pd.read_csv('who_pays.csv')

# %%
#Create a list of those links from the dataframe
link_list = df_pubs.link.tolist()

#test the first few entries 
print(link_list[:3])
# len(link_list)
# Out:
# ['http://whopayswriters.com/#/publication/100-days-in-appalachia', 'http://whopayswriters.com/#/publication/3288-review', 'http://whopayswriters.com/#/publication/425-business']

# %% [markdown]
# ## Step 2:
# Write the loop that will crawl *ALL* the pages and run the code you wrote below

# %%
'''Right now, this code successfully pulls the URL from the list and enters it into the driver
The problem is: the last page is the only one that loads. The others load, but are overwritten
Maybe this will change when I've written the code to scrape the info from the individual pages
this should slow the loop down
'''
#we're using a short list, only 4 elements from the full list to test. This should be changed 
short_list = link_list[:3]
for link in short_list:
    driver = webdriver.Chrome()
    driver.get(link)

# %% [markdown]
# ## Sidebar: write the code that will scrape the page
# We're looking to get at least the price per word, and the details of the published piece

# %%
#we're pointing this at a test page. Later, we'll white-label it so it works with the loop that
#opens pages
driver_test= webdriver.Chrome()
driver_test.get('http://whopayswriters.com/#/publication/100-days-in-appalachia')

# %%
boxes = driver_test.find_elements_by_class_name('card')
rows = []
for box in boxes:
    print('----')
    row={}
    descriptions = box.find_elements_by_tag_name('p')
    row['money'] = box.find_element_by_class_name('dollaz').text
    row['description'] = descriptions[0].text
    row['details'] = descriptions[2].text
    rows.append(row)
print(rows)
# Out:
# ----
# ----
# ----
# ----
# [{'money': '$0.17\n/word', 'description': '1200-word opinion, editorial, column or essay', 'details': 'Medium reporting; Cold pitch (no pre-existing relationship)'}, {'money': '$0.20\n/word', 'description': '1200-word criticism, review, or arts/entertainment coverage', 'details': 'Medium reporting; Cold pitch (no pre-existing relationship)'}, {'money': '$0.23\n/word', 'description': '1100-word feature', 'details': 'Heavy/Investigative reporting; Solicited pitch (editor asked you to pitch)'}, {'money': '$0.20\n/word', 'description': '1500-word criticism, review, or arts/entertainment coverage', 'details': 'Medium reporting; Ongoing/pre-existing relationship with editor or publication'}]

# %%
#testing another page for compatitbility

# %%
#test on a new page
driver_test= webdriver.Chrome()
driver_test.get('http://whopayswriters.com/#/publication/wall-street-journal')

# %%
boxes = driver_test.find_elements_by_class_name('card')
rows = []
for box in boxes:
    print('----')
    row={}
    descriptions = box.find_elements_by_tag_name('p')
    row['money'] = box.find_element_by_class_name('dollaz').text
    row['description'] = descriptions[0].text
    row['details'] = descriptions[2].text
    rows.append(row)
print(rows)
# Out:
# ----
# ----
# ----
# ----
# ----
# ----
# [{'money': '$0.50\n/word', 'description': '1000-word profile or interview', 'details': 'Medium reporting; Referral (you had a connection who connected you to the editor)'}, {'money': '$0.50\n/word', 'description': '800-word opinion, editorial, column or essay', 'details': 'Little to no reporting; Cold pitch (no pre-existing relationship)'}, {'money': '$1.07\n/word', 'description': '~750-word news story', 'details': 'Medium reporting; Ongoing/pre-existing relationship with editor or publication'}, {'money': '', 'description': '', 'details': ''}, {'money': '$0.50\n/word', 'description': '800-word opinion, editorial, column or essay', 'details': ''}, {'money': '$0.55\n/word', 'description': '~1100-word criticism, review, or arts/entertainment converage', 'details': ''}]

# %% [markdown]
# ## Combine the scrape and the loop

# %%
short_list = link_list
rows = []
driver = webdriver.Chrome()
counter = 1
out_of = len(short_list)
for link in short_list:
    driver.get(link)
    boxes = driver.find_elements_by_class_name('card')
#     year = driver.find_elements_by_class_name('text-right ng-binding')
    driver.implicitly_wait(3)
    print('starting to scrape the next page. Currently on ', counter, ' out of ', out_of)
    try:
        for box in boxes:
            print('starting to scrape the info from this page')
            pub_name = str.split(link, '/')
            row={}
            descriptions = box.find_elements_by_tag_name('p')
            row['money'] = box.find_element_by_class_name('dollaz').text
            row['description'] = descriptions[0].text
            row['details'] = descriptions[2].text
            row['pub_name'] = pub_name[-1]
            rows.append(row)

            print('finished one loop')
    #         print('here is the results of this loop', row)
    except:
        pass
    counter = counter + 1
# print(rows)
df_full = pd.DataFrame(rows)
# Out:
# starting to scrape the next page. Currently on  1  out of  1297
# starting to scrape the next page. Currently on  1  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  2  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  3  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  4  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  5  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  8  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  10  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  13  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  14  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  16  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  17  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  19  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  21  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  23  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  24  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  25  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  26  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  27  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  33  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  37  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  38  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  39  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  40  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  49  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  55  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  66  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  67  out of  1297
# starting to scrape the next page. Currently on  67  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  68  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  69  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  71  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  80  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  81  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  92  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  93  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  94  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  96  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  98  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  99  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  100  out of  1297
# starting to scrape the next page. Currently on  100  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  101  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  102  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  103  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  105  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  106  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  108  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  110  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  111  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  114  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  115  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  116  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  117  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  118  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  122  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  123  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  124  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  131  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  135  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  137  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  140  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  146  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  148  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  151  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  152  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  153  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  154  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  162  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  164  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  170  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  176  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  177  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  179  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  180  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  182  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  184  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  187  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  188  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  191  out of  1297
# starting to scrape the next page. Currently on  191  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  192  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  193  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  213  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  216  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  226  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  227  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  228  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  229  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  231  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  234  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  237  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  238  out of  1297
# starting to scrape the next page. Currently on  238  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  239  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  240  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  241  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  242  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  245  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  247  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  251  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  253  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  254  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  256  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  257  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  259  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  260  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  261  out of  1297
# starting to scrape the next page. Currently on  261  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  262  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  263  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  267  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  268  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  271  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  301  out of  1297
# starting to scrape the next page. Currently on  301  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  302  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  304  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  305  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  306  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  308  out of  1297
# starting to scrape the next page. Currently on  308  out of  1297
# starting to scrape the next page. Currently on  308  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  309  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  310  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  312  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  313  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  319  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  320  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  322  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  323  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  327  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  330  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  331  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  332  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  333  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  335  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  336  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  339  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  340  out of  1297
# starting to scrape the next page. Currently on  340  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  341  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  342  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  344  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  348  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  358  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  366  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  367  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  368  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  369  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  376  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  380  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  381  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  382  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  383  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  384  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  385  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  388  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  399  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  410  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  420  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  421  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  425  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  426  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  427  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  428  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  432  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  433  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  434  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  435  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  436  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  438  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  439  out of  1297
# starting to scrape the next page. Currently on  439  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  440  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  441  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  447  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  448  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  450  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  451  out of  1297
# starting to scrape the next page. Currently on  451  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  452  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  453  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  454  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  456  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  457  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  458  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  459  out of  1297
# starting to scrape the next page. Currently on  459  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  461  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  462  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  468  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  470  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  472  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  473  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  474  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  476  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  479  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  483  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  484  out of  1297
# starting to scrape the next page. Currently on  484  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  485  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  488  out of  1297
# starting to scrape the next page. Currently on  488  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  497  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  499  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  500  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  501  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  502  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  504  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  505  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  506  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  507  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  509  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  512  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  513  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  514  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  520  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  521  out of  1297
# starting to scrape the next page. Currently on  521  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  522  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  531  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  534  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  535  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  539  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  540  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# ...
# finished one loop
# starting to scrape the next page. Currently on  2873  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  2875  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  2876  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  2885  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  2890  out of  1297
# starting to scrape the next page. Currently on  2890  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  2892  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  2893  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  2898  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  2899  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  2904  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  2905  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  2911  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  2912  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  2915  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  2919  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  2920  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  2926  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  2927  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  2928  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  2931  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  2951  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  2953  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  2955  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  2957  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  2960  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  2962  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  2963  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  2964  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  2965  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  2966  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  2967  out of  1297
# starting to scrape the next page. Currently on  2967  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  2970  out of  1297
# starting to scrape the next page. Currently on  2970  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  2971  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  2972  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  2973  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  2974  out of  1297
# starting to scrape the next page. Currently on  2974  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  2975  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  2977  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  2978  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  2985  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  2986  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  2987  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  2988  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  2989  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  2990  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  2991  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  2993  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  2994  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  2995  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  2997  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  2998  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  2999  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  3000  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  3001  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  3002  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  3003  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  3005  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  3006  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  3030  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  3031  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  3032  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  3033  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  3034  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  3037  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  3038  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  3039  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  3040  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  3045  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  3046  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  3047  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  3048  out of  1297
# starting to scrape the info from this page
# finished one loop
# starting to scrape the info from this page
# finished one loop
# starting to scrape the next page. Currently on  3050  out of  1297
# starting to scrape the info from this page
# finished one loop

# %%
df_full.to_csv('who_pays_final.csv', index = False)

# %%
# Out:
#                                          description  \
# 0      1200-word opinion, editorial, column or essay
# 1  1200-word criticism, review, or arts/entertain...
# 2                                  1100-word feature
# 3                                          1000-word
# 4  1500-word criticism, review, or arts/entertain...
# 5                                  1200-word fiction
# 6                    ~1500-word profile or interview
#
#                                              details         money  \
# 0  Medium reporting; Cold pitch (no pre-existing ...  $0.17\n/word
# 1  Medium reporting; Cold pitch (no pre-existing ...  $0.20\n/word
# 2  Heavy/Investigative reporting; Solicited pitch...  $0.23\n/word
# 3                                                     $0.10\n/word
# 4  Medium reporting; Ongoing/pre-existing relatio...  $0.20\n/word
# 5  Medium reporting; Cold pitch (no pre-existing ...  $0.02\n/word
# 6  Medium reporting; Ongoing/pre-existing relatio...  $0.15\n/word
#
#                  pub_name
# 0  100-days-in-appalachia
# 1  100-days-in-appalachia
# 2  100-days-in-appalachia
# 3  100-days-in-appalachia
# 4  100-days-in-appalachia
# 5             3288-review
# 6            425-business

# %%
box = driver.find_elements_by_class_name('card')[0]

# %%
money = box.find_element_by_class_name('dollaz').text

# %%
re.match(money, '')
