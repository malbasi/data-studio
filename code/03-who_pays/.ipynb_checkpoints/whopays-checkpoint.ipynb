# %%
import pandas as pd
import matplotlib.pyplot as plt
from pygeocoder import Geocoder
import numpy as np
from cycler import cycler
import re

import glob

# %matplotlib inline

# %%
#Import style
plt.rcdefaults()
plt.rcParams.update({
    'pdf.fonttype': 42,
    'ps.fonttype': 42,
    'font.family': 'Futura Std',
    'font.style' : 'normal',
    'font.weight' : '100',
    'font.stretch' : 'ultra-condensed',
    
    'figure.facecolor'    : '#FDF6E3',

    
    'patch.antialiased'   : True,

    'lines.linewidth'     : 2.0,
    'lines.solid_capstyle': 'butt',

    'axes.titlesize'      : 16,
    'axes.labelsize'      : 12,
    'axes.labelcolor'     : '#657b83',
    'axes.facecolor'      : '#eee8d5',
    'axes.edgecolor'      : '#eee8d5',
    'axes.axisbelow'      : True,
    'axes.prop_cycle'    : cycler('color', ['#268BD2','#d26c3d', '#dbd7ad', '#f6c5af', '#d7da00', '#7db49f', '#86a3ba']),

    'axes.grid'           : False,
    'grid.color'          : '#ffffff',    # grid color
    'grid.linestyle'      : ':',         # line
    'grid.linewidth'      : 1,        # in points

    ### TICKS
    'xtick.color'         : '#657b83',
    'xtick.direction'     : 'out',
    'xtick.labelsize' : 14,
    'ytick.labelsize' : 14,

    'ytick.color'         : '#657b83',
    'ytick.direction'     : 'out',
    
})

# %%
df = pd.read_csv("who_pays_final.csv")
df.head()
# Out:
#                        description  \
# 0                1200 word fiction
# 1  ~1500 word profile or interview
# 2                 700 word feature
# 3              500 word news story
# 4   2000 word profile or interview
#
#                                              details         money  \
# 0  Medium reporting; Cold pitch (no pre existing ...  $0.02\n/word
# 1  Medium reporting; Ongoing/pre existing relatio...  $0.15\n/word
# 2  Medium reporting; Ongoing/pre existing relatio...  $0.21\n/word
# 3                                                NaN  $0.07\n/word
# 4  Medium reporting; Cold pitch (no pre existing ...  $0.06\n/word
#
#        pub_name
# 0   3288 review
# 1  425 business
# 2          5280
# 3           7x7
# 4       av club

# %%
df[['rate','type']]=df.money.str.extract('\$(\d*.\d*)\\n/*(\w*)')
df.head()
# Out:
#                        description  \
# 0                1200 word fiction
# 1  ~1500 word profile or interview
# 2                 700 word feature
# 3              500 word news story
# 4   2000 word profile or interview
#
#                                              details         money  \
# 0  Medium reporting; Cold pitch (no pre existing ...  $0.02\n/word
# 1  Medium reporting; Ongoing/pre existing relatio...  $0.15\n/word
# 2  Medium reporting; Ongoing/pre existing relatio...  $0.21\n/word
# 3                                                NaN  $0.07\n/word
# 4  Medium reporting; Cold pitch (no pre existing ...  $0.06\n/word
#
#        pub_name  rate  type
# 0   3288 review  0.02  word
# 1  425 business  0.15  word
# 2          5280  0.21  word
# 3           7x7  0.07  word
# 4       av club  0.06  word

# %%
df['rate'] = df.rate.astype(float)
df.head()
# Out:
#                        description  \
# 0                1200 word fiction
# 1  ~1500 word profile or interview
# 2                 700 word feature
# 3              500 word news story
# 4   2000 word profile or interview
#
#                                              details         money  \
# 0  Medium reporting; Cold pitch (no pre existing ...  $0.02\n/word
# 1  Medium reporting; Ongoing/pre existing relatio...  $0.15\n/word
# 2  Medium reporting; Ongoing/pre existing relatio...  $0.21\n/word
# 3                                                NaN  $0.07\n/word
# 4  Medium reporting; Cold pitch (no pre existing ...  $0.06\n/word
#
#        pub_name  rate  type
# 0   3288 review  0.02  word
# 1  425 business  0.15  word
# 2          5280  0.21  word
# 3           7x7  0.07  word
# 4       av club  0.06  word

# %%
#Drop obvious miscategorizations
df.drop(df.index[[1822,860,583, 2979, 1971, 1696, 1689]], inplace=True)

# %%
df[df.pub_name == 'playboy']
# Out:
#                                             description  \
# 1684  1300 word criticism, review, or arts/entertain...
# 1685                                  1600 word feature
# 1686                                          3600 word
# 1687                                  1500 word feature
# 1688                                   800 word feature
# 1690     ~1500 word opinion, editorial, column or essay
# 1691  1300 word criticism, review, or arts/entertain...
# 1692                                  1600 word feature
# 1693                                          3600 word
# 1694                                  1500 word feature
# 1695                                   800 word feature
# 1697     ~1500 word opinion, editorial, column or essay
#
#                                                 details         money  \
# 1684  Medium reporting; Cold pitch (no pre existing ...  $0.00\n/word
# 1685  Medium reporting; Assignment (editor came to you)  $0.31\n/word
# 1686                      Heavy/Investigative reporting  $2.00\n/word
# 1687  Medium reporting; Solicited pitch (editor aske...  $0.33\n/word
# 1688  Little to no reporting; Cold pitch (no pre exi...  $0.29\n/word
# 1690  Medium reporting; Cold pitch (no pre existing ...  $0.17\n/word
# 1691  Medium reporting; Cold pitch (no pre existing ...  $0.00\n/word
# 1692  Medium reporting; Assignment (editor came to you)  $0.31\n/word
# 1693                      Heavy/Investigative reporting  $2.00\n/word
# 1694  Medium reporting; Solicited pitch (editor aske...  $0.33\n/word
# 1695  Little to no reporting; Cold pitch (no pre exi...  $0.29\n/word
# 1697  Medium reporting; Cold pitch (no pre existing ...  $0.17\n/word
#
#      pub_name  rate  type
# 1684  playboy  0.00  word
# 1685  playboy  0.31  word
# 1686  playboy  2.00  word
# 1687  playboy  0.33  word
# 1688  playboy  0.29  word
# 1690  playboy  0.17  word
# 1691  playboy  0.00  word
# 1692  playboy  0.31  word
# 1693  playboy  2.00  word
# 1694  playboy  0.33  word
# 1695  playboy  0.29  word
# 1697  playboy  0.17  word

# %%
df.head()
# Out:
#                        description  \
# 0                1200 word fiction
# 1  ~1500 word profile or interview
# 2                 700 word feature
# 3              500 word news story
# 4   2000 word profile or interview
#
#                                              details         money  \
# 0  Medium reporting; Cold pitch (no pre existing ...  $0.02\n/word
# 1  Medium reporting; Ongoing/pre existing relatio...  $0.15\n/word
# 2  Medium reporting; Ongoing/pre existing relatio...  $0.21\n/word
# 3                                                NaN  $0.07\n/word
# 4  Medium reporting; Cold pitch (no pre existing ...  $0.06\n/word
#
#        pub_name  rate  type
# 0   3288 review  0.02  word
# 1  425 business  0.15  word
# 2          5280  0.21  word
# 3           7x7  0.07  word
# 4       av club  0.06  word

# %%
# drop n/a's (Only from money column)
df = df.dropna(subset=['money'])

# %%
# df.loc[df.money.str.contains("flat", na=False), "flat_rate"] = df.money.str.extract('\$(\d*.\d*)')
# df.loc[~df.money.str.contains("flat", na=False), "per_word"] = df.money.str.extract('\$(\d*.\d*)')

# %%
# Make a seperate DF, df_per, to hold only entries that were paid per word 
df_per = df[df['type'] != 'flat']

# %% [markdown]
# # Is there a more interesting way to show this than a bar chart?
# # If not:
# ### Drop the dupes and fill.
# ### X Make all bars the same color
# ### X drop the legend
# ### X drop the axis labels (do in rcparam)

# %%
ax_rate = df_per.sort_values(by='rate', ascending=False).head(11).plot(kind='barh', x='pub_name', y='rate', color='#268BD2', figsize=(10,5))
ax_rate.grid(True, axis='x')
ax_rate.legend_.remove()
plt.savefig('dist.svg')
plt.show()

# %%
df_per[df_per.pub_name == 'vogue']
# Out:
#                                         description  \
# 2892                                      3000 word
# 2893                            719 word news story
# 2894                                      1000 word
# 2895  1000 word opinion, editorial, column or essay
# 2896                                  ~375 word fob
#
#                                                 details         money  \
# 2892                                                NaN  $3.00\n/word
# 2893  Medium reporting; Cold pitch (no pre existing ...  $0.28\n/word
# 2894  Medium reporting; Cold pitch (no pre existing ...  $0.20\n/word
# 2895  Medium reporting; Cold pitch (no pre existing ...  $0.25\n/word
# 2896  Medium reporting; Assignment (editor came to you)  $2.00\n/word
#
#      pub_name  rate  type
# 2892    vogue  3.00  word
# 2893    vogue  0.28  word
# 2894    vogue  0.20  word
# 2895    vogue  0.25  word
# 2896    vogue  2.00  word

# %%
#This is an attempt to drop duplicate bars

# df_per.groupby('pub_name', squeeze=True).head(10).plot(kind='barh', x='pub_name', y='rate', color='#268BD2')
# plt.show()

# %% [markdown]
# # This is probably almost good
# ### Set the bin width so it's more clear and reflect real breaks in salary (think \$0.50 and \$1.00 instead of \$1.33)
# ### change all but the first bar to grey?

# %%
hist = df_per.rate.value_counts(normalize=True)*100
ax_hist = hist.plot(kind='hist', bins=[0,.5,1,1.5,2,2.5,3], figsize=(10,5))
ax_hist.grid(True, axis='y')
plt.savefig('hist.svg')
plt.show()

# %%
hist
# Out:
# 0.10    5.463097
# 0.20    5.137482
# 0.00    5.028944
# 0.25    4.775687
# 0.13    4.739508
# 0.07    4.594790
# 0.03    4.377713
# 0.05    3.907381
# 0.50    3.835022
# 1.00    3.726483
# 0.33    3.183792
# 0.04    3.039074
# 0.17    2.894356
# 0.02    2.424023
# 0.15    2.243126
# 0.30    2.206946
# 0.06    2.026049
# 0.40    1.989870
# 0.08    1.917511
# 0.27    1.555716
# 0.21    1.410999
# 0.19    1.374819
# 0.09    1.374819
# 0.01    1.193922
# 0.29    1.085384
# 0.11    1.049204
# 0.14    0.976845
# 2.00    0.976845
# 0.12    0.940666
# 0.35    0.904486
#           ...
# 0.79    0.072359
# 0.58    0.072359
# 0.62    0.072359
# 1.26    0.072359
# 0.59    0.072359
# 0.90    0.072359
# 3.67    0.072359
# 2.40    0.036179
# 1.39    0.036179
# 2.31    0.036179
# 1.04    0.036179
# 1.35    0.036179
# 0.68    0.036179
# 1.08    0.036179
# 1.01    0.036179
# 1.12    0.036179
# 1.10    0.036179
# 0.93    0.036179
# 0.51    0.036179
# 0.92    0.036179
# 1.82    0.036179
# 2.08    0.036179
# 0.91    0.036179
# 1.47    0.036179
# 0.89    0.036179
# 1.19    0.036179
# 0.61    0.036179
# 1.40    0.036179
# 1.43    0.036179
# 1.14    0.036179
# Name: rate, Length: 117, dtype: float64
